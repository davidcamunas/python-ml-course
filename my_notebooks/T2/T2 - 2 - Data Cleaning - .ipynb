# %% [markdown]
# # Funciones de distribución uniforme de probabilidades

# %% [markdown]
# ## Distribución Uniforme

# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = 1
b = 100
n = 2000000
data = np.random.uniform(a, b, n)
data
# Out:
# array([15.95510932, 27.2921371 , 52.71116622, ..., 81.21561199,
#        85.63184391, 71.95691567])

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([199764., 200092., 200280., 200181., 199929., 199572., 200141.,
#         199743., 200012., 200286.]),
#  array([ 1.0000425 , 10.90003802, 20.80003353, 30.70002905, 40.60002457,
#         50.50002008, 60.4000156 , 70.30001112, 80.20000664, 90.10000215,
#         99.99999767]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Distribución Normal (Campana de Gauss)

# %%
data = np.random.randn(1000000)
data
# Out:
# array([ 0.21750317, -1.43152588, -1.07750294, ...,  0.60159881,
#         1.03892316,  1.34724923])

# %%
x = range(1,1000001)
plt.plot(x, data)

# %%
plt.hist(data)
# Out:
# (array([4.90000e+01, 1.50500e+03, 2.11040e+04, 1.19695e+05, 3.03603e+05,
#         3.41380e+05, 1.70480e+05, 3.82650e+04, 3.73100e+03, 1.88000e+02]),
#  array([-4.79706572, -3.86479798, -2.93253023, -2.00026249, -1.06799474,
#         -0.135727  ,  0.79654074,  1.72880849,  2.66107623,  3.59334398,
#          4.52561172]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x, sorted(data))

# %% [markdown]
# En este caso si ordenan los datos, sale la función de distribución acumulada.
# Las fucniones gaussianas tienen esta forma, ya que al principio crece poco y al final crece bastante.

# %%
mu = 5.5
sd = 2.5
data = mu + sd * np.random.randn(10000)
plt.hist(data)
# Out:
# (array([  30.,  191.,  806., 1884., 2776., 2481., 1311.,  424.,   84.,
#           13.]),
#  array([-3.27390555, -1.43183916,  0.41022723,  2.25229361,  4.09436   ,
#          5.93642639,  7.77849277,  9.62055916, 11.46262555, 13.30469193,
#         15.14675832]),
#  <BarContainer object of 10 artists>)
